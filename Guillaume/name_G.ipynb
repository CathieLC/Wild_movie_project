# %% [markdown]
# ## Load name.basics.tsv

# %%
import pandas as pd
import numpy as np

# %%
name_df = pd.read_csv("https://datasets.imdbws.com/name.basics.tsv.gz", sep="\t")

# %%
name_df.head(10)
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
# 5  nm0000006   Ingrid Bergman      1915      1982
# 6  nm0000007  Humphrey Bogart      1899      1957
# 7  nm0000008    Marlon Brando      1924      2004
# 8  nm0000009   Richard Burton      1925      1984
# 9  nm0000010     James Cagney      1899      1986
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
# 5          actress,soundtrack,producer
# 6            actor,soundtrack,producer
# 7            actor,soundtrack,director
# 8            actor,soundtrack,producer
# ...

# %%
name_df.tail(10)
# Out:
#              nconst         primaryName birthYear deathYear  \
# 11362745  nm9993709           Lu Bevins        \N        \N
# 11362746  nm9993710   Nestor Rudnytskyy        \N        \N
# 11362747  nm9993711       David Gluzman        \N        \N
# 11362748  nm9993712     Corny O'Connell        \N        \N
# 11362749  nm9993713       Sambit Mishra        \N        \N
# 11362750  nm9993714   Romeo del Rosario        \N        \N
# 11362751  nm9993716       Essias Loberg        \N        \N
# 11362752  nm9993717  Harikrishnan Rajan        \N        \N
# 11362753  nm9993718         Aayush Nair        \N        \N
# 11362754  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 11362745             director,producer,writer
# 11362746                                  NaN
# 11362747                                  NaN
# 11362748                                  NaN
# 11362749                               writer
# ...

# %%
name_df.replace('\\N', np.nan, inplace=True)

# %%
name_df.sort_values(by=['birthYear'], ascending=True).head(20)
# Out:
#               nconst           primaryName birthYear deathYear  \
# 739770     nm0784172    Lucio Anneo Seneca      0004      0065
# 6783714    nm4511421       Megan Liz Smith      0012       NaN
# 10356392   nm8810146            Paul Walsh      0021       NaN
# 407676     nm0430769      Flavius Josephus      0037      0095
# 3902529    nm1306202              Plutarch      0046      0122
# 487351     nm0515385          Titus Livius      0059      0017
# 3907526    nm1306711             Suetonius      0069      0140
# 3881512    nm1304029                Appian      0095      0165
# 3765509    nm1291933           Cassius Dio      0163      0235
# 3277782    nm1240835            Augustinus      0354      0430
# 3305004   nm12436700             Aristotle      0384      0322
# 8147163    nm6063582            Yiqing Liu      0403      0444
# 6210361    nm3840780              Muhammad      0570      0632
# 4206539    nm1602457               Einhard      0770      0840
# ...
