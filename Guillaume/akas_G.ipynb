# %% [markdown]
# ## Load title.akas.tsv

# %%
import pandas as pd
import numpy as np

# %%
akas_df = pd.read_csv("https://datasets.imdbws.com/title.akas.tsv.gz", sep="\t", dtype={'isOriginalTitle': str})

# %%
akas_df.head(20)
# Out:
#       titleId  ordering                      title region language  \
# 0   tt0000001         1                 Карменсіта     UA       \N
# 1   tt0000001         2                 Carmencita     DE       \N
# 2   tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3   tt0000001         4                 Καρμενσίτα     GR       \N
# 4   tt0000001         5                 Карменсита     RU       \N
# 5   tt0000001         6                 Carmencita     US       \N
# 6   tt0000001         7                 Carmencita     \N       \N
# 7   tt0000001         8                    カルメンチータ     JP       ja
# 8   tt0000002         1     Le clown et ses chiens     \N       \N
# 9   tt0000002         2     Le clown et ses chiens     FR       \N
# 10  tt0000002         3          A bohóc és kutyái     HU       \N
# 11  tt0000002         4  Der Clown und seine Hunde     DE       \N
# 12  tt0000002         5      Clovnul si cainii sai     RO       \N
# ...

# %%
akas_df.tail(10)
# Out:
#             titleId  ordering           title region language        types  \
# 29865899  tt9916850         7     Folge #3.19     DE       de           \N
# 29865900  tt9916852         1  Episodio #3.20     ES       es           \N
# 29865901  tt9916852         2   Épisode #3.20     FR       fr           \N
# 29865902  tt9916852         3     Folge #3.20     DE       de           \N
# 29865903  tt9916852         4     エピソード #3.20     JP       ja           \N
# 29865904  tt9916852         5  Episódio #3.20     PT       pt           \N
# 29865905  tt9916852         6  Episodio #3.20     IT       it           \N
# 29865906  tt9916852         7    एपिसोड #3.20     IN       hi           \N
# 29865907  tt9916856         1        The Wind     DE       \N  imdbDisplay
# 29865908  tt9916856         2        The Wind     \N       \N     original
#
#          attributes isOriginalTitle
# 29865899         \N               0
# 29865900         \N               0
# ...

# %%
akas_df.replace('\\N', np.nan)
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 29865904  tt9916852         5             Episódio #3.20     PT       pt
# 29865905  tt9916852         6             Episodio #3.20     IT       it
# 29865906  tt9916852         7               एपिसोड #3.20     IN       hi
# 29865907  tt9916856         1                   The Wind     DE      NaN
# 29865908  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# ...

# %%
akas_df[akas_df.titleId == 'tt9914928']
# Out:
#             titleId  ordering            title region language        types  \
# 29862877  tt9914928         1  Noblesse Oblige     \N       \N     original
# 29862878  tt9914928         2  Noblesse Oblige     GB       \N  imdbDisplay
#
#          attributes isOriginalTitle
# 29862877         \N               1
# 29862878         \N               0

# %%
akas_df[akas_df.titleId == 'tt9916852']
# Out:
#             titleId  ordering           title region language types  \
# 29865900  tt9916852         1  Episodio #3.20     ES       es    \N
# 29865901  tt9916852         2   Épisode #3.20     FR       fr    \N
# 29865902  tt9916852         3     Folge #3.20     DE       de    \N
# 29865903  tt9916852         4     エピソード #3.20     JP       ja    \N
# 29865904  tt9916852         5  Episódio #3.20     PT       pt    \N
# 29865905  tt9916852         6  Episodio #3.20     IT       it    \N
# 29865906  tt9916852         7    एपिसोड #3.20     IN       hi    \N
#
#          attributes isOriginalTitle
# 29865900         \N               0
# 29865901         \N               0
# 29865902         \N               0
# 29865903         \N               0
# 29865904         \N               0
# 29865905         \N               0
# 29865906         \N               0
