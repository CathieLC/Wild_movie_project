# %% [markdown]
# ## Load title.akas.tsv

# %%
import pandas as pd
import numpy as np

# %%
akas_df = pd.read_csv("https://datasets.imdbws.com/title.akas.tsv.gz", sep="\t", dtype={'isOriginalTitle': str})

# %%
akas_df.head(10)
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
# 5  tt0000001         6                 Carmencita     US       \N
# 6  tt0000001         7                 Carmencita     \N       \N
# 7  tt0000001         8                    カルメンチータ     JP       ja
# 8  tt0000002         1     Le clown et ses chiens     \N       \N
# 9  tt0000002         2     Le clown et ses chiens     FR       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0
# 5  imdbDisplay             \N               0
# 6     original             \N               1
# 7  imdbDisplay             \N               0
# 8     original             \N               1
# 9  imdbDisplay             \N               0

# %%
akas_df.tail(10)
# Out:
#             titleId  ordering           title region language        types  \
# 29699525  tt9916850         7     Folge #3.19     DE       de           \N
# 29699526  tt9916852         1  Episodio #3.20     ES       es           \N
# 29699527  tt9916852         2   Épisode #3.20     FR       fr           \N
# 29699528  tt9916852         3     Folge #3.20     DE       de           \N
# 29699529  tt9916852         4     エピソード #3.20     JP       ja           \N
# 29699530  tt9916852         5  Episódio #3.20     PT       pt           \N
# 29699531  tt9916852         6  Episodio #3.20     IT       it           \N
# 29699532  tt9916852         7    एपिसोड #3.20     IN       hi           \N
# 29699533  tt9916856         1        The Wind     DE       \N  imdbDisplay
# 29699534  tt9916856         2        The Wind     \N       \N     original
#
#          attributes isOriginalTitle
# 29699525         \N               0
# 29699526         \N               0
# 29699527         \N               0
# 29699528         \N               0
# 29699529         \N               0
# 29699530         \N               0
# 29699531         \N               0
# 29699532         \N               0
# 29699533         \N               0
# 29699534         \N               1

# %%
akas_df.replace('\\N', np.nan)
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA      NaN
# 1         tt0000001         2                 Carmencita     DE      NaN
# 2         tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3         tt0000001         4                 Καρμενσίτα     GR      NaN
# 4         tt0000001         5                 Карменсита     RU      NaN
# ...             ...       ...                        ...    ...      ...
# 29699530  tt9916852         5             Episódio #3.20     PT       pt
# 29699531  tt9916852         6             Episodio #3.20     IT       it
# 29699532  tt9916852         7               एपिसोड #3.20     IN       hi
# 29699533  tt9916856         1                   The Wind     DE      NaN
# 29699534  tt9916856         2                   The Wind    NaN      NaN
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay            NaN               0
# 1                 NaN  literal title               0
# 2         imdbDisplay            NaN               0
# 3         imdbDisplay            NaN               0
# 4         imdbDisplay            NaN               0
# ...               ...            ...             ...
# 29699530          NaN            NaN               0
# 29699531          NaN            NaN               0
# 29699532          NaN            NaN               0
# 29699533  imdbDisplay            NaN               0
# 29699534     original            NaN               1
#
# [29699535 rows x 8 columns]

# %%
akas_df[akas_df.titleId == 'tt9914928']
# Out:
#             titleId  ordering            title region language        types  \
# 29696466  tt9914928         1  Noblesse Oblige     \N       \N     original
# 29696467  tt9914928         2  Noblesse Oblige     GB       \N  imdbDisplay
#
#          attributes isOriginalTitle
# 29696466         \N               1
# 29696467         \N               0

# %%
akas_df[akas_df.titleId == 'tt9916852']
# Out:
#             titleId  ordering           title region language types  \
# 29699526  tt9916852         1  Episodio #3.20     ES       es    \N
# 29699527  tt9916852         2   Épisode #3.20     FR       fr    \N
# 29699528  tt9916852         3     Folge #3.20     DE       de    \N
# 29699529  tt9916852         4     エピソード #3.20     JP       ja    \N
# 29699530  tt9916852         5  Episódio #3.20     PT       pt    \N
# 29699531  tt9916852         6  Episodio #3.20     IT       it    \N
# 29699532  tt9916852         7    एपिसोड #3.20     IN       hi    \N
#
#          attributes isOriginalTitle
# 29699526         \N               0
# 29699527         \N               0
# 29699528         \N               0
# 29699529         \N               0
# 29699530         \N               0
# 29699531         \N               0
# 29699532         \N               0
